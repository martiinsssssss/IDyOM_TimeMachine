# %%
import os

# %%
import pandas
import matplotlib
import seaborn
import math
import scipy
import sklearn
import statsmodels
import numpy
import pretty_midi
import json
import collection
import ruptures

# %%
! pip show collection --version
# Out:
# Name: collection
# Version: 0.1.6
# Summary: Laravel-style collection class that provides an interface for pipeline programming
# Home-page: https://github.com/thenerdscribe/collection
# Author: Ryan Morton
# Author-email: thenerdscribe@gmail.com
# License: MIT
# Location: /Users/arianapereira/miniconda3/envs/idyom_env/lib/python3.10/site-packages
# Requires:
# Required-by:
